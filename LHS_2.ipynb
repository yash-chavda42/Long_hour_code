# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/"MyDrive/dataset_ml/LHC/LHC"
# Out:
# /content/drive/MyDrive/dataset_ml/LHC/LHC

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#task5 Determine the ratio of duplicate questions asked in each month
dataset_link=pd.read_csv("Arjun_Assignment_data/dataset1/postLinks.csv")
dataset_link
# Out:
#          Unnamed: 0          id            creation_date   post_id  \
# 0                 0          19  2010-04-26T02:59:48.130       109
# 1                 1          37  2010-04-26T02:59:48.600      1970
# 2                 2          42  2010-04-26T02:59:48.647      2154
# 3                 3          48  2010-04-26T02:59:48.740      2483
# 4                 4          52  2010-04-26T02:59:48.757      2572
# ...             ...         ...                      ...       ...
# 5292619     5292619  1624278139  2018-09-02T08:09:41.520  52133002
# 5292620     5292620  1624278147  2018-09-02T08:10:50.820  52134991
# 5292621     5292621  1624278315  2018-09-02T08:14:26.470  52135049
# 5292622     5292622  1624278337  2018-09-02T08:15:36.387  52135007
# 5292623     5292623  1624278449  2018-09-02T08:17:32.137  52135049
#
#          related_post_id  link_type_id
# 0                  32412             1
# 1                 617600             1
# 2                2451138             1
# ...

# %%
link_type_id=dataset_link.values[:,5]
print(link_type_id)
# Out:
# [1 1 1 ... 1 1 1]

# %%
creation_date=dataset_link.values[:,2]
print(creation_date)
# Out:
# ['2010-04-26T02:59:48.130' '2010-04-26T02:59:48.600'
#  '2010-04-26T02:59:48.647' ... '2018-09-02T08:14:26.470'
#  '2018-09-02T08:15:36.387' '2018-09-02T08:17:32.137']

# %%
creation_date[1]
# Out:
# '2010-04-26T02:59:48.600'

# %%
date=list()
cou=0
for i in range(len(link_type_id)):
    x = creation_date[i].split("-")
    x.pop()
    #print(x)
    s = "-".join(x)
    #print(s)
    date.append(s)

# %%
date_ = {}
# iterating over the list
for item in date:
   # checking the element in dictionary
   if item in date_:
      # incrementing the counr
      date_[item] += 1
   else:
      # initializing the count
      date_[item] = 1

# printing the frequency
print(date_)
# Out:
# {'2010-04': 64929, '2010-05': 9694, '2010-06': 9970, '2010-07': 12223, '2010-08': 13035, '2010-09': 12160, '2010-10': 15658, '2010-11': 11271, '2010-12': 12579, '2011-01': 15235, '2011-02': 16095, '2011-03': 20326, '2011-04': 20291, '2011-05': 21516, '2011-06': 21159, '2011-07': 20640, '2011-08': 23547, '2011-09': 22482, '2011-10': 21523, '2011-11': 24417, '2011-12': 23682, '2012-01': 27080, '2012-02': 28406, '2012-03': 31014, '2012-04': 30419, '2012-05': 32648, '2012-06': 33684, '2012-07': 36523, '2012-08': 37212, '2012-09': 34575, '2012-10': 40624, '2012-11': 34818, '2012-12': 32224, '2013-01': 39888, '2013-02': 111122, '2013-03': 47197, '2013-04': 46580, '2013-05': 45152, '2013-06': 42975, '2013-07': 47928, '2013-08': 47272, '2013-09': 42882, '2013-10': 46718, '2013-11': 44179, '2013-12': 47656, '2014-01': 58275, '2014-02': 60164, '2014-03': 69193, '2014-04': 61171, '2014-05': 66296, '2014-06': 59276, '2014-07': 63403, '2014-08': 57601, '2014-09': 57104, '2014-10': 57973, '2014-11
# ...

# %%
len(date_)
# Out:
# 102

# %%
count=0
for i in link_type_id:
  if(i==3):
    count+=1
print(count)
# Out:
# 682329

# %%
#this one for duplication means link_type_id as 3
date_list_3=list()
count1=0
for i in range(len(link_type_id)):
  if(link_type_id[i]==3):
    x = creation_date[i].split("-")
    x.pop()
    #print(x)
    s = "-".join(x)
    #print(s)
    date_list_3.append(s)

# %%
print(len(date_list_3))
# Out:
# 682329

# %%
date_list_3
# Out:
# ['2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
#  '2013-02',
# ...

# %%
date_frequency_3 = {}

# iterating over the list
for item in date_list_3:
   # checking the element in dictionary
   if item in date_frequency_3:
      # incrementing the counr
      date_frequency_3[item] += 1
   else:
      # initializing the count
      date_frequency_3[item] = 1

# printing the frequency
print(date_frequency_3)
# Out:
# {'2013-02': 75344, '2013-03': 5579, '2013-04': 4895, '2013-05': 4620, '2013-06': 4434, '2013-07': 4424, '2013-08': 4402, '2013-09': 3467, '2013-10': 3533, '2013-11': 3170, '2013-12': 4651, '2014-01': 4101, '2014-02': 5519, '2014-03': 10816, '2014-04': 6365, '2014-05': 9403, '2014-06': 7586, '2014-07': 7348, '2014-08': 6287, '2014-09': 6688, '2014-10': 6461, '2014-11': 5490, '2014-12': 6264, '2015-01': 6305, '2015-02': 5485, '2015-03': 6643, '2015-04': 7741, '2015-05': 7996, '2015-06': 7928, '2015-07': 7677, '2015-08': 7964, '2015-09': 8306, '2015-10': 8805, '2015-11': 9064, '2015-12': 9700, '2016-01': 9350, '2016-02': 9846, '2016-03': 10477, '2016-04': 11112, '2016-05': 10860, '2016-06': 11502, '2016-07': 10314, '2016-08': 10482, '2016-09': 10492, '2016-10': 11095, '2016-11': 10895, '2016-12': 10034, '2017-01': 11170, '2017-02': 10790, '2017-03': 12666, '2017-04': 11470, '2017-05': 11601, '2017-06': 12079, '2017-07': 12540, '2017-08': 13441, '2017-09': 12946, '2017-10': 14116, '2017-
# ...

# %%
len(date_frequency_3)
# Out:
# 68

# %%
#this one for non_duplication means for link_type_id as 1
date_list_1=list()
count1=0
for i in range(len(link_type_id)):
  if(link_type_id[i]==1):
    x = creation_date[i].split("-")
    x.pop()
    #print(x)
    s = "-".join(x)
    #print(s)
    date_list_1.append(s)

# %%
print(len(date_list_1))
# Out:
# 4610295

# %%
date_frequency_1 = {}

# iterating over the list
for item in date_list_1:
   # checking the element in dictionary
   if item in date_frequency_1:
      # incrementing the counr
      date_frequency_1[item] += 1
   else:
      # initializing the count
      date_frequency_1[item] = 1

# printing the frequency
print(date_frequency_1)
# Out:
# {'2010-04': 64929, '2010-05': 9694, '2010-06': 9970, '2010-07': 12223, '2010-08': 13035, '2010-09': 12160, '2010-10': 15658, '2010-11': 11271, '2010-12': 12579, '2011-01': 15235, '2011-02': 16095, '2011-03': 20326, '2011-04': 20291, '2011-05': 21516, '2011-06': 21159, '2011-07': 20640, '2011-08': 23547, '2011-09': 22482, '2011-10': 21523, '2011-11': 24417, '2011-12': 23682, '2012-01': 27080, '2012-02': 28406, '2012-03': 31014, '2012-04': 30419, '2012-05': 32648, '2012-06': 33684, '2012-07': 36523, '2012-08': 37212, '2012-09': 34575, '2012-10': 40624, '2012-11': 34818, '2012-12': 32224, '2013-01': 39888, '2013-02': 35778, '2013-03': 41618, '2013-04': 41685, '2013-05': 40532, '2013-06': 38541, '2013-07': 43504, '2013-08': 42870, '2013-09': 39415, '2013-10': 43185, '2013-11': 41009, '2013-12': 43005, '2014-01': 54174, '2014-02': 54645, '2014-03': 58377, '2014-04': 54806, '2014-05': 56893, '2014-06': 51690, '2014-07': 56055, '2014-08': 51314, '2014-09': 50416, '2014-10': 51512, '2014-11'
# ...

# %%
len(date_frequency_1)
# Out:
# 102

# %%
date_frequency_1.values()
# Out:
# dict_values([64929, 9694, 9970, 12223, 13035, 12160, 15658, 11271, 12579, 15235, 16095, 20326, 20291, 21516, 21159, 20640, 23547, 22482, 21523, 24417, 23682, 27080, 28406, 31014, 30419, 32648, 33684, 36523, 37212, 34575, 40624, 34818, 32224, 39888, 35778, 41618, 41685, 40532, 38541, 43504, 42870, 39415, 43185, 41009, 43005, 54174, 54645, 58377, 54806, 56893, 51690, 56055, 51314, 50416, 51512, 47950, 47054, 51111, 49593, 56328, 59850, 59412, 59904, 62406, 58266, 57787, 60255, 58180, 59424, 63030, 63356, 67319, 65832, 66052, 64641, 61806, 63838, 60703, 61367, 61734, 58244, 63909, 61021, 68739, 61778, 64098, 62014, 64279, 65240, 58911, 61349, 61237, 53575, 60089, 57116, 64711, 60249, 61012, 55575, 57568, 58490, 1322])

# %%
class my_dictionary(dict):
  
    # __init__ function
    def __init__(self):
        self = dict()
          
    # Function to add key:value
    def add(self, key, value):
        self[key] = value

# %%
list_1_val=list(date_frequency_1.values())
list_1_key=list(date_frequency_1.keys())
list_3_val=list(date_frequency_3.values())
list_3_key=list(date_frequency_3.keys())

# %%
coun=0
new_ratio = []
new_date = []
for z in range(len(list_1_val)):
  flag=0
  #if list_1_key[z] in list_3_key:
  for y in range(len(list_3_val)):
      if list_1_key[z]==list_3_key[y]:
        val3=list_3_val[y]
        flag=1
  if(flag==0):
      val3=0
  ratio=val3/list_1_val[y]
  #print(ratio)
  new_date.append(list_1_key[z])
  new_ratio.append(ratio)

# %%
ans_dict = my_dictionary()
print("month    ->  ratio")
for z in range(len(new_date)):
  ans_dict.add(new_date[z],new_ratio[z])
  print(new_date[z]," -> ",new_ratio[z])
# Out:
# month    ->  ratio
# 2010-04  ->  0.0
# 2010-05  ->  0.0
# 2010-06  ->  0.0
# 2010-07  ->  0.0
# 2010-08  ->  0.0
# 2010-09  ->  0.0
# 2010-10  ->  0.0
# 2010-11  ->  0.0
# 2010-12  ->  0.0
# 2011-01  ->  0.0
# 2011-02  ->  0.0
# 2011-03  ->  0.0
# 2011-04  ->  0.0
# 2011-05  ->  0.0
# 2011-06  ->  0.0
# 2011-07  ->  0.0
# 2011-08  ->  0.0
# 2011-09  ->  0.0
# 2011-10  ->  0.0
# 2011-11  ->  0.0
# 2011-12  ->  0.0
# 2012-01  ->  0.0
# 2012-02  ->  0.0
# 2012-03  ->  0.0
# 2012-04  ->  0.0
# 2012-05  ->  0.0
# 2012-06  ->  0.0
# 2012-07  ->  0.0
# 2012-08  ->  0.0
# 2012-09  ->  0.0
# 2012-10  ->  0.0
# 2012-11  ->  0.0
# 2012-12  ->  0.0
# 2013-01  ->  0.0
# 2013-02  ->  1.2950154692334135
# 2013-03  ->  0.09589205912684771
# 2013-04  ->  0.08413544173255415
# 2013-05  ->  0.07940873152286008
# 2013-06  ->  0.0762117566173943
# 2013-07  ->  0.07603987624613269
# 2013-08  ->  0.07566173942935717
# 2013-09  ->  0.05959092471639739
# 2013-10  ->  0.06072533516672396
# ...

# %%
courses = list(ans_dict.keys())
values = list(ans_dict.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='red',
        width = 0.4)
 
plt.xlabel("Tags")
plt.ylabel("Persantage")
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
x = np.linspace(-2, 2, 10)
y = np.exp(x)
plt.xlabel('ratio', fontsize=14)
plt.ylabel('data', fontsize=14)
plt.plot(new_date, new_ratio, color='red')
spacing = 0.100
fig.subplots_adjust(bottom=spacing)
plt.show()

# %%
#Task6 Determine the percentage of duplicate questions associated with different tags
id=dataset_link.values[:,1]
id = id.tolist()
id
# Out:
# [19,
#  37,
#  42,
#  48,
#  52,
#  58,
#  59,
#  63,
#  69,
#  70,
#  72,
#  74,
#  75,
#  76,
#  81,
#  84,
#  90,
#  96,
#  119,
#  121,
#  126,
#  128,
#  130,
#  131,
#  134,
#  142,
#  144,
#  149,
#  150,
#  162,
#  164,
#  166,
#  168,
#  170,
#  178,
#  184,
#  185,
#  187,
#  197,
#  198,
#  199,
#  206,
#  211,
#  217,
#  218,
#  219,
#  220,
#  221,
#  223,
#  228,
#  229,
#  234,
#  236,
#  237,
#  244,
#  247,
#  249,
#  250,
#  254,
#  256,
#  257,
#  258,
#  266,
#  269,
#  270,
#  275,
#  276,
#  283,
#  284,
#  287,
#  288,
#  289,
#  290,
#  297,
#  309,
#  312,
#  314,
#  317,
#  318,
#  319,
#  321,
#  322,
#  327,
#  329,
#  330,
#  336,
#  338,
#  339,
#  340,
#  349,
#  350,
#  353,
#  355,
#  357,
#  358,
#  363,
#  365,
#  370,
#  373,
#  385,
#  386,
#  398,
#  401,
#  404,
#  410,
#  419,
#  420,
#  421,
#  427,
#  429,
#  435,
#  439,
#  441,
#  442,
#  446,
#  447,
#  449,
#  450,
#  453,
#  455,
#  457,
#  458,
#  460,
#  462,
#  463,
#  464,
#  465,
# ...

# %%
#this one for duplication means link_type_id as 3
id_tag_du=list()

for i in range(len(link_type_id)):
  if(link_type_id[i]==3):
    id_tag_du.append(id[i])

# %%
#this are duplicate questions id
print(len(id_tag_du))
id_tag_du
# Out:
# 682329
# [749670241,
#  749670246,
#  749670247,
#  749670248,
#  749670249,
#  749670250,
#  749670251,
#  749670252,
#  749670253,
#  749670254,
#  749670255,
#  749670256,
#  749670257,
#  749670258,
#  749670259,
#  749670260,
#  749670261,
#  749670262,
#  749670263,
#  749670264,
#  749670265,
#  749670266,
#  749670267,
#  749670268,
#  749670269,
#  749670270,
#  749670271,
#  749670272,
#  749670273,
#  749670274,
#  749670275,
#  749670276,
#  749670277,
#  749670278,
#  749670279,
#  749670280,
#  749670281,
#  749670282,
#  749670283,
#  749670284,
#  749670285,
#  749670286,
#  749670287,
#  749670288,
#  749670289,
#  749670290,
#  749670291,
#  749670292,
#  749670293,
#  749670295,
#  749670296,
#  749670297,
#  749670298,
#  749670299,
#  749670300,
#  749670301,
#  749670302,
#  749670303,
#  749670304,
#  749670305,
#  749670306,
#  749670307,
#  749670308,
#  749670309,
#  749670310,
#  749670311,
#  749670312,
#  749670313,
#  749670314,
#  749670315,
# ...

# %%
dataset_long=pd.read_csv("Arjun_Assignment_data/dataset1/posts_long.csv")
dataset_long
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Unnamed: 0        id  post_type_id  accepted_answer_id  parent_id  \
# 0                0         4             1                   7       -999
# 1                1         6             1                  31       -999
# 2                2         9             1                1404       -999
# 3                3        11             1                1248       -999
# 4                4        13             1                -999       -999
# ...            ...       ...           ...                 ...        ...
# 676199      676199  52133457             1                -999       -999
# 676200      676200  52133674             1                -999       -999
# 676201      676201  52133700             1                -999       -999
# ...

# %%
#task1 find no of tag per question
tag_long=dataset_long.values[:,9]
tag_long_id=dataset_long.values[:,1]
taglong2=list()
tagsl=list()
mergelist=list()
for i in range(len(tag_long)):
  x = tag_long[i].split("<")    
  s = "".join(x)
  x = s.split(">")
  x.pop()
  taglong2.append(x)
  tagsl.append(len(x)) 
  for j in x:
    mergelist.append(j)

# %%
print(tag_long_id)
print(tag_long_id.shape)
tag_long_id = tag_long_id.tolist()
# Out:
# [4 6 9 ... 52133700 52133880 52134121]
# (676204,)

# %%
print(len(id))
# Out:
# 5292624

# %%
print(len(taglong2))
taglong2
# Out:
# 676204
# [['c#', 'floating-point', 'type-conversion', 'double', 'decimal'],
#  ['html', 'css', 'css3', 'internet-explorer-7'],
#  ['c#', '.net', 'datetime'],
#  ['c#', 'datetime', 'time', 'datediff', 'relative-time-span'],
#  ['javascript', 'html', 'browser', 'timezone', 'timezoneoffset'],
#  ['.net', 'math'],
#  ['mysql', 'database', 'binary-data', 'data-storage'],
#  ['mysql', 'database', 'triggers'],
#  ['sql', 'sql-server', 'datatable', 'rdbms'],
#  ['php', 'plugins', 'architecture', 'hook'],
#  ['html', 'form-submit', 'html-form', 'submit-button'],
#  ['c#', 'linq', '.net-3.5'],
#  ['linux', 'winapi', 'visual-c++', 'unix', 'timer'],
#  ['svn', 'tortoisesvn', 'branch', 'branching-and-merging'],
#  ['.net', 'performance', 'memory-leaks', 'com-interop'],
#  ['java', 'xml', 'csv', 'data-conversion'],
#  ['java', 'php', 'oop', 'theory'],
#  ['mysql', 'sql-server', 'csv', 'sql-server-2005', 'bcp'],
#  ['sql-server', 'database', 'svn', 'version-control'],
# ...

# %%
print(len(tag_long_id))
print(demo_list)
# Out:
# 676204
# []

# %%
flag=0
demo_list=[]
for z in range(len(tag_long_id)):
  if(tag_long_id[z] in id_tag_du):
    demo_list.append(tag_long_id[z])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-1bb8e84143ff> in <module>()
#       2 demo_list=[]
#       3 for z in range(len(tag_long_id)):
# ----> 4   if(tag_long_id[z] in id_tag_du):
#       5     demo_list.append(tag_long_id[z])
#       6
#
# KeyboardInterrupt:

# %%
if(749670241 in tag_long_id):
    print("yes")
else:
    print("no")
# Out:
# no

# %%
flag=0
for z in range(len(id_tag_du)):
  flag=0  
  for y in range(len(tag_long_id)):
      if id_tag_du[z]==tag_long_id[y]:
        
        flag=1
  if(flag==0):
      val3=0
  ratio=val3/list_1_val[y]
  #print(ratio)
  new_date.append(list_1_key[z])
  new_ratio.append(ratio)

# %%
#task2 find unique tag
Unique_tag = {}

# iterating over the list
for item in mergelist:
   # checking the element in dictionary
   if item in Unique_tag:
      # incrementing the counr
      Unique_tag[item] += 1
   else:
      # initializing the count
      Unique_tag[item] = 1

# printing unique tag with their frequncy
print(Unique_tag)
